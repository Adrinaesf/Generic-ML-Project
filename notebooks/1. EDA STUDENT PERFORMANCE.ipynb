# %% [markdown]
# # Stduent Performance Indicator
#
# ## Life cycle of Machine Learning Project:
#
# * Understanding teh problem statment
# * Data Collection
# * Data checks to perform
# * Explotary data analyst (eda)
# * Data Per-processing
# * Model Training
# * Choose the best model
#
# ## How to understand the steps:
# * Step 1: the question. **Decide what question you're answering.**
# * Step 2: get data. Do we actually have data that can answer this problem? (if so, Get the information you'll learn from.)
# * Steps 3: validate data. **Can I trust this data?**

# %% [markdown]
# # 1) **Problem statement**
# * This project understands how the student's performance (test scores) is affected by other variables such as Gender, Ethnicity, Parental level of education, Lunch and Test preparation course.

# %% [markdown]
# # 2) **Data Collection:**
# * Download the data from kaggle and put it in ``notebooks/data``. Provice the number of column and rows:
# * The data consist of 8 colomns and 1000 rows.

# %% [markdown]
# ### 2.1) Import the data and required packages.
# * Import ``Pandas, Numpy, Matplotlib, Seaborn`` and Warning libraries.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### 2.2) Import the CSV Data as Pandas DataFrame

# %%
df = pd.read_csv('data/stud.csv')

# Showing the top 5 records: 
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# ### 2.3) Check the shape of the data:

# %%
df.shape
# Out:
# (1000, 8)

# %% [markdown]
# ### 2.4) Data Information:
# * gender : sex of students -> (Male/female)
# * race/ethnicity : ethnicity of students -> (Group A, B, C, D,E)
# * parental level of education : parents' final education ->(bachelor's degree,some college,master's degree,associate's degree,high school)
# * lunch : having lunch before test (standard or free/reduced)
# * test preparation course : complete or not complete before test
# * math score
# * reading score
# * writing score

# %% [markdown]
# # 3) **Data Checks to Perform**
# * Check Missing values
# * Check Duplicates
# * Check data type
# * Check the number of unique values of each column
# * Check statistics of data set
# * Check various categories present in the different categorical column

# %% [markdown]
# ### 3.1) Check Missing Values:
# If many values are missing, you'll need to decide whether to:
# 1. remove rows,
# 2. fill in missing values,
# 3. or collect better data.

# %%
# 3.1 Check number of missing values:
df.isna().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# Total Score                    0
# Average of Scores              0
# dtype: int64

# %% [markdown]
# ### 3.2 Check Duplicates:

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### 3.3 Check data types

# %%
# 3.3 Check data types
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   str
#  1   race/ethnicity               1000 non-null   str
#  2   parental level of education  1000 non-null   str
#  3   lunch                        1000 non-null   str
#  4   test preparation course      1000 non-null   str
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
#  8   Total Score                  1000 non-null   int64
#  9   Average of Scores            1000 non-null   float64
# dtypes: float64(1), int64(4), str(5)
# memory usage: 78.3 KB

# %% [markdown]
# ### 3.4 Check the number of unique values in each colunm:

# %%
# 3.4 Check the number of unique values in each colunm:
df.nunique()
# Out:
# gender                           2
# race/ethnicity                   5
# parental level of education      6
# lunch                            2
# test preparation course          2
# math score                      81
# reading score                   72
# writing score                   77
# Total Score                    194
# Average of Scores              194
# dtype: int64

# %% [markdown]
# ### 3.5 Check Statics of Data

# %%
# 3.5 Check Statics of Data
df.describe()
# Out:
#        math score  reading score  writing score  Total Score  \
# count  1000.00000    1000.000000    1000.000000  1000.000000
# mean     66.08900      69.169000      68.054000   203.312000
# std      15.16308      14.600192      15.195657    42.771978
# min       0.00000      17.000000      10.000000    27.000000
# 25%      57.00000      59.000000      57.750000   175.000000
# 50%      66.00000      70.000000      69.000000   205.000000
# 75%      77.00000      79.000000      79.000000   233.000000
# max     100.00000     100.000000     100.000000   300.000000
#
#        Average of Scores
# count        1000.000000
# mean           67.770667
# std            14.257326
# min             9.000000
# 25%            58.333333
# 50%            68.333333
# 75%            77.666667
# max           100.000000

# %% [markdown]
# **Insight**
#
# * From above description of numerical data, all means are very close to each other - between 66 and 68.05;
# * All standard deviations are also close - between 14.6 and 15.19;
# * While there is a minimum score 0 for math, for writing minimum is much higher = 10 and for reading myet higher = 17

# %% [markdown]
# ### 3.6 Exploring the data:

# %%
# 3.6 Exploring the data:
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    Total Score  Average of Scores
# 0          218          72.666667
# 1          247          82.333333
# 2          278          92.666667
# ...

# %%
print("Categories in 'gender' variable:     ",end=" " )
print(df['gender'].unique())
print()
print("Categories in 'race_ethnicity' variable:  ",end=" ")
print(df['race/ethnicity'].unique())
print()
print("Categories in'parental level of education' variable:",end=" " )
print(df['parental level of education'].unique())
print()
print("Categories in 'lunch' variable:     ",end=" " )
print(df['lunch'].unique())
print()
print("Categories in 'test preparation course' variable:     ",end=" " )
print(df['test preparation course'].unique())
# Out:
# Categories in 'gender' variable:      <StringArray>
# ['female', 'male']
# Length: 2, dtype: str
#
# Categories in 'race_ethnicity' variable:   <StringArray>
# ['group B', 'group C', 'group A', 'group D', 'group E']
# Length: 5, dtype: str
#
# Categories in'parental level of education' variable: <StringArray>
# [ 'bachelor's degree',       'some college',    'master's degree',
#  'associate's degree',        'high school',   'some high school']
# Length: 6, dtype: str
#
# Categories in 'lunch' variable:      <StringArray>
# ['standard', 'free/reduced']
# Length: 2, dtype: str
#
# Categories in 'test preparation course' variable:      <StringArray>
# ['none', 'completed']
# Length: 2, dtype: str

# %% [markdown]
# ### 3.7 define numerical & categorical columns

# %%
# define numerical & categorical columns
numeric_features = [feature for feature in df.columns if df[feature].dtype == 'int64']
categorical_features = [feature for feature in df.columns if df[feature].dtype != 'int64']

# print columns
print(df["math score"].dtype)
print('We have {} numerical features : {}'.format(len(numeric_features), numeric_features))
print('\nWe have {} categorical features : {}'.format(len(categorical_features), categorical_features))
# Out:
# int64
# We have 4 numerical features : ['math score', 'reading score', 'writing score', 'Total Score']
#
# We have 6 categorical features : ['gender', 'race/ethnicity', 'parental level of education', 'lunch', 'test preparation course', 'Average of Scores']

# %% [markdown]
# ### 3.8 Adding columns for "Total Score" and "Average"

# %%
# 3.8 Adding columns for "Total Score" and "Average"
df["Total Score"] = df["math score"] + df["writing score"] + df["reading score"]
df["Average of Scores"] = df["Total Score"] / 3
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    Total Score  Average of Scores
# 0          218          72.666667
# 1          247          82.333333
# 2          278          92.666667
# ...

# %%
reading_full = df[df["reading score"] == 100]["Average of Scores"].count()
math_full = df[df["math score"] == 100]["Average of Scores"].count()
writing_full = df[df["writing score"] == 100]["Average of Scores"].count()

print(f'Number of students with full marks in Maths: {math_full}')
print(f'Number of students with full marks in Writing: {writing_full}')
print(f'Number of students with full marks in Reading: {reading_full}')
# Out:
# Number of students with full marks in Maths: 7
# Number of students with full marks in Writing: 14
# Number of students with full marks in Reading: 17

# %%
reading_less_20 = df[df['reading score'] <= 20]['Average of Scores'].count()
writing_less_20 = df[df['writing score'] <= 20]['Average of Scores'].count()
math_less_20 = df[df['math score'] <= 20]['Average of Scores'].count()

print(f'Number of students with less than 20 marks in Maths: {math_less_20}')
print(f'Number of students with less than 20 marks in Writing: {writing_less_20}')
print(f'Number of students with less than 20 marks in Reading: {reading_less_20}')
# Out:
# Number of students with less than 20 marks in Maths: 4
# Number of students with less than 20 marks in Writing: 3
# Number of students with less than 20 marks in Reading: 1

# %% [markdown]
# **Insights**
# * From above values we get students have performed the worst in Maths
# * Best performance is in reading section

# %% [markdown]
# # 4) **Data Visualization**

# %% [markdown]
# ### 4.1 Visualize average and total score distribution
# * Histogram
# * Kernel Distribution Function (KDE)

# %%
fig, axes = plt.subplots(
    nrows = 1, 
    ncols = 2, 
    figsize = (12,6)
)

sns.histplot(
    data = df, 
    x = "Average of Scores", 
    bins=30, 
    kde=True, 
    color='g', 
    ax = axes[0]
)

sns.histplot(
    data = df, 
    x = "Average of Scores", 
    bins=30, 
    kde=True, 
    hue="gender",
    ax = axes[1]
)
# Out:
# <Axes: xlabel='Average of Scores', ylabel='Count'>

# %%
fig, axes = plt.subplots(
    nrows = 1, 
    ncols = 2, 
    figsize = (12,6)
)

sns.histplot(
    data = df, 
    x = "Total Score", 
    bins=30, 
    kde=True, 
    color='g', 
    ax = axes[0]
)

sns.histplot(
    data = df, 
    x = "Total Score", 
    bins=30, 
    kde=True, 
    hue="gender",
    ax = axes[1]
)
# Out:
# <Axes: xlabel='Total Score', ylabel='Count'>

# %% [markdown]
# **Insights:**
#
# * Female students tent to perform well than male students

# %% [markdown]
# #### 4.1.2 Visualize average score with lunch effect
# * Graph it for all the students to see the overall effect of lunch on their performance.
# * Graph it for female students.
# * Graph it for male students

# %%
# Graph it as subplot:
fig, axes = plt.subplots(
    nrows = 1, 
    ncols = 3, 
    figsize = (25, 6)
)

female_df = df[df["gender"] == "female"]
male_df = df[df["gender"] == "male"]

sns.histplot(
    data = df, 
    x = "Average of Scores", 
    hue = "lunch", 
    ax = axes[0]
)

female_plt_lunch = sns.histplot(
    data = female_df, 
    x = "Average of Scores", 
    hue = "lunch", 
    ax = axes[1], 
    kde = True
)

female_plt_lunch.set_xlabel("Average Score (female)")

male_plt_lunch = sns.histplot(
    data = male_df, 
    x = "Average of Scores", 
    hue = "lunch", 
    ax = axes[2], 
    kde = True
)

male_plt_lunch.set_xlabel("Average Score (male)")
# Out:
# Text(0.5, 0, 'Average Score (male)')

# %% [markdown]
# **Insights**:
#
# * We can see overall who had standad lunch had a higher average compare to students who had free/reduced lunch.
#
# * Standard lunch helps perform well in exams be it a male or a female.

# %% [markdown]
# #### 4.1.2 Visualize average score with parental level of education effect

# %%
# Graph it as subplot:
fig, axes = plt.subplots(
    nrows = 1, 
    ncols = 3, 
    figsize = (25, 6)
)

sns.histplot(
    data = df, 
    x = "Average of Scores", 
    hue = "parental level of education",
    kde = True,
    ax = axes[0]
)

female_plt_edu = sns.histplot(
    data = female_df, 
    x = "Average of Scores", 
    hue = "parental level of education", 
    ax = axes[1], 
    kde = True
)

female_plt_edu.set_xlabel("Average Score (female)")

male_plt_edu = sns.histplot(
    data = male_df, 
    x = "Average of Scores", 
    hue = "parental level of education", 
    ax = axes[2], 
    kde = True
)

male_plt_edu.set_xlabel("Average Score (male)")
# Out:
# Text(0.5, 0, 'Average Score (male)')

# %%
fig, axes = plt.subplots(
    nrows = 1, 
    ncols = 3, 
    figsize = (25,6)
)

sns.histplot(
    data = df, 
    x = "Average of Scores", 
    hue = "race/ethnicity",
    kde = True,
    ax = axes[0]
)

female_plt_race = sns.histplot(
    data = female_df, 
    x = "Average of Scores", 
    hue = "race/ethnicity", 
    ax = axes[1], 
    kde = True
)

female_plt_race.set_xlabel("Average Score (female)")

male_plt_race = sns.histplot(
    data = male_df, 
    x = "Average of Scores", 
    hue = "race/ethnicity", 
    ax = axes[2], 
    kde = True
)

male_plt_race.set_xlabel("Average Score (male)")
# Out:
# Text(0.5, 0, 'Average Score (male)')

# %% [markdown]
# ### 4.2 Maximum score of studnets in all three subjects

# %%
plt.figure(figsize=(18,8))
plt.subplot(1, 4, 1)
plt.title('MATH SCORES')
sns.violinplot(y='math score',data=df,color='red',linewidth=3)
plt.subplot(1, 4, 2)
plt.title('READING SCORES')
sns.violinplot(y='reading score',data=df,color='green',linewidth=3)
plt.subplot(1, 4, 3)
plt.title('WRITING SCORES')
sns.violinplot(y='writing score',data=df,color='blue',linewidth=3)
plt.show()

# %% [markdown]
# **Insights**
#
# * From the above three plots its clearly visible that most of the students score in between 60-80 in Maths whereas in reading and writing most of them score from 50-80

# %% [markdown]
# ### 4.3 Multivariate analysis using pieplot

# %%
# Setting the default size of pie graphs to (30, 12)
plt.rcParams["figure.figsize"] = (30, 12)

fig, axes = plt.subplots(
    nrows = 1, 
    ncols = 5
)
# -----------------------------------------------------
# info nfor the first pie chart:
# 1. We need the number of elements in each category. 
# 2. Labels
# 3. colors
plt.subplot(1, 5, 1)
size = df["gender"].value_counts()
labels = "Female", "Male"
colors = ["pink", "blue"]

axes[0].pie(
    size, 
    colors = colors, 
    labels = labels, 
    autopct = '.%1.1f%%'
)

plt.title('Gender', fontsize = 20)
plt.axis('off')

# --------------------------------------------------
plt.subplot(1, 5, 2)
size = df['race/ethnicity'].value_counts()
labels = 'Group C', 'Group D','Group B','Group E','Group A'
color = ['red', 'green', 'blue', 'cyan','orange']

axes[1].pie(
    size, 
    colors = color,
    labels = labels,
    autopct = '.%1.1f%%'
)

plt.title('Race/Ethnicity', fontsize = 20)
plt.axis('off')

# --------------------------------------------------
plt.subplot(1, 5, 3)
size = df['lunch'].value_counts()
labels = 'Standard', 'Free'
color = ['red','green']

plt.pie(size, colors = color,labels = labels,autopct = '.%2f%%')
plt.title('Lunch', fontsize = 20)
plt.axis('off')

# --------------------------------------------------
plt.subplot(1, 5, 4)
size = df['test preparation course'].value_counts()
labels = 'None', 'Completed'
color = ['red','blue']

plt.pie(size, colors = color,labels = labels,autopct = '.%2f%%')
plt.title('Test Course', fontsize = 20)
plt.axis('off')

# --------------------------------------------------
plt.subplot(1, 5, 5)
size = df['parental level of education'].value_counts()
labels = 'Some College', "Associate's Degree",'High School','Some High School',"Bachelor's Degree","Master's Degree"
color = ['red', 'green', 'blue', 'cyan','orange','grey']

plt.pie(size, colors = color,labels = labels,autopct = '.%2f%%')
plt.title('Parental Education', fontsize = 20)
plt.axis('off')

# --------------------------------------------------
plt.tight_layout()
plt.grid()

plt.show()

# %% [markdown]
# **Insights**
#
# * Number of Male and Female students is almost equal
# * Number students are greatest in Group C
# * Number of students who have standard lunch are greater
# * Number of students who have not enrolled in any test preparation course is greater
# * Number of students whose parental education is "Some College" is greater followed closely by "Associate's Degree"

# %% [markdown]
# ### 4.4 Feature Wise Visualization

# %% [markdown]
# #### 4.4.1 GENDER COLUMN
# * How is the distribution of gender? (categorical dist)
# * How gender affect student's performance?

# %% [markdown]
# ##### UNIVARIATE ANALYSIS ( How is distribution of Gender ? )

# %%
fig, axes = plt.subplots(
    nrows = 1, 
    ncols = 2, 
    figsize = (20, 10)
)

sns.countplot(
    x = df["gender"], 
    data = df, 
    palette ='bright', 
    ax = axes[0], 
    saturation=0.95
)

for container in axes[0].containers:
    axes[0].bar_label(container,size=20)

axes[1].pie(
    x=df['gender'].value_counts(),
    labels=['Male','Female'],
    explode=[0,0.1],
    autopct='%1.1f%%',
    shadow=True,
    colors=['#ff4d4d','#ff8000']
)

plt.show()

# %% [markdown]
# **Insights**
#
# * Gender has balanced data with female students are 518 (48%) and male students are 482 (52%)

# %% [markdown]
# ##### BIVARIATE ANALYSIS ( Is gender has any impact on student's performance ? )

# %%
gender_group = df.groupby("gender").mean
gender_group
# Out:
# <bound method GroupBy.mean of <pandas.api.typing.DataFrameGroupBy object at 0x121234210>>

# %%
# Goal: How gender affected students performance:
fig, axes = plt.subplots(
    nrows = 1, 
    ncols = 2, 
    figsize = (30,10)
)

sns.barplot(
    data = df, 
    x = "gender", 
    y = "Average of Scores", 
    palette = "bright",
    ax = axes[0]
)

for container in axes[0].containers:
    axes[0].bar_label(container,size=20)

sns.barplot(
    data = df, 
    x = "gender", 
    y = "math score", 
    palette = "dark",
    ax = axes[1]
)

for container in axes[1].containers:
    axes[1].bar_label(container,size=20)

# %% [markdown]
# **Insights**
# * On an average females have a better overall score than men.
# * Whereas males have scored higher in Maths.

# %% [markdown]
# #### 4.4.2 RACE/EHNICITY COLUMN
# * How is group wise distribution? (categorical dist)
# * Is race/ethnicity affects student's performance?

# %% [markdown]
# ##### UNIVARIATE ANALYSIS ( How is Group wise distribution ?)

# %%
fig, axes = plt.subplots(
    nrows = 1, 
    ncols = 2, 
    figsize = (30,10)
)

sns.countplot(
    data = df, 
    x = df["race/ethnicity"], 
    palette = "bright", 
    ax = axes[0]
)

for container in axes[0].containers:
    axes[0].bar_label(container, size=20)

size = df["race/ethnicity"].value_counts()
labels = df['race/ethnicity'].value_counts().index
plt.pie(
    x = size,
    labels = labels,
    explode=[0.1,0,0,0,0],
    autopct='%1.1f%%',
    shadow=True
)
plt.show()

# %% [markdown]
# **Insights**
# * Most of the student belonging from group C /group D.
# * Lowest number of students belong to group A.

# %% [markdown]
# ##### BIVARIATE ANALYSIS ( Is Race/Ehnicity has any impact on student's performance ? )

# %%
Group_2_race=df.groupby('race/ethnicity')
Group_2_race.first()
# Out:
#                 gender parental level of education         lunch  \
# race/ethnicity
# group A           male          associate's degree  free/reduced
# group B         female           bachelor's degree      standard
# group C         female                some college      standard
# group D           male                 high school  free/reduced
# group E         female             master's degree  free/reduced
#
#                test preparation course  math score  reading score  \
# race/ethnicity
# group A                           none          47             57
# group B                           none          72             72
# group C                      completed          69             90
# group D                      completed          64             64
# group E                           none          56             72
#
#                 writing score  Total Score  Average of Scores
# race/ethnicity
# group A                    44          148          49.333333
# ...

# %%
# Since we want to see the math score for each race, and not all the students, 
# we group the results by the race they have:
# This way we can see multiple statics:
# like race vs math median, or math max scores 

fig, axes = plt.subplots(
    nrows = 1, 
    ncols = 3, 
    figsize = (20,8)
)

race_labels = Group_2_race["math score"].mean().index

# -----------------------------------------------
sns.barplot(
    x = race_labels, 
    y = Group_2_race["math score"].mean().values, 
    palette = "mako", 
    ax = axes[0]
)
axes[0].set_title('Math score',color='#005ce6',size=20)
axes[0].set_ylabel("math score")

for container in axes[0].containers:
    axes[0].bar_label(container, size = 15)

# -----------------------------------------------
sns.barplot(
    x = race_labels, 
    y = Group_2_race["reading score"].mean().values, 
    palette = "flare", 
    ax = axes[1]
)
axes[1].set_title("Reading score", color='#005ce6', size=20)
axes[1].set_ylabel("reading score")

for container in axes[1].containers:
    axes[1].bar_label(container, size=15)
# -----------------------------------------------
sns.barplot(
    x = labels, 
    y = Group_2_race["writing score"].mean().values, 
    palette = "coolwarm", 
    ax = axes[2]
)
axes[2].set_title('Writing score', color='#005ce6',size=20)
axes[2].set_ylabel("writing score")

for container in axes[2].containers:
    axes[2].bar_label(container, size=15)

# %% [markdown]
# **Insights**
# * Group E students have scored the highest marks.
# * Group A students have scored the lowest marks.
# * Students from a lower Socioeconomic status have a lower avg in all course subjects.

# %% [markdown]
# #### 4.4.3 PARENTAL LEVEL OF EDUCATION COLUMN
# * What is educational background of student's parents?
# * Is that affect student's performance?

# %% [markdown]
# ##### UNIVARIATE ANALYSIS ( What is educational background of student's parent ? )

# %%
plt.figure(figsize=(15,9))

sns.countplot(
    data = df, 
    x = df["parental level of education"], 
    palette = "Blues"
)

plt.title('Comparison of Parental Education', fontweight = 30, fontsize = 20)
plt.xlabel('Degree')
plt.ylabel('count')
plt.show()
# Out:
# findfont: Failed to find font weight 30, now using 400.

# %% [markdown]
# **Insights**
# * Largest number of parents are from some college.

# %% [markdown]
# ##### BIVARIATE ANALYSIS ( Is parental education has any impact on student's performance ? )

# %%
plt.figure(figsize=(15,9))

Group_3_parentedu = df.groupby("parental level of education")
labels = Group_3_parentedu["Average of Scores"].mean().index
sns.barplot(
    x = labels, 
    y = Group_3_parentedu["Average of Scores"].mean().values, 
    palette = "flare"
)
plt.title("Student performance with parental level of edu")
plt.ylabel("Average of Scores")
plt.show()

# %% [markdown]
# **Insights**
# * The score of student whose parents possess master and bachelor level education are higher than others.

# %% [markdown]
# #### 4.4.4 LUNCH COLUMN
# * Which type of lunch is most common amoung students ?
# * What is the effect of lunch type on test results?

# %% [markdown]
# ##### UNIVARIATE ANALYSIS ( Which type of lunch is most common amoung students ? )

# %%
fig, axes = plt.subplots(
    nrows = 1, 
    ncols = 2, 
    figsize = (30,10)
)

sns.countplot(
    data = df, 
    x = df["lunch"], 
    palette = "PuBu", 
    ax = axes[0]
)

for container in axes[0].containers:
    axes[0].bar_label(container, size=20)

size = df["lunch"].value_counts()
labels = df["lunch"].value_counts().index

plt.pie(
    x = size, 
    labels = labels, 
    autopct='%1.1f%%',
    explode=[0.1,0],
    shadow=True
)

# %% [markdown]
# **Insights**
# * Students being served Standard lunch (64.5%) was more than free lunch (35.5%)

# %% [markdown]
# ##### BIVARIATE ANALYSIS ( Is lunch type intake has any impact on student's performance ? )

# %%
plt.figure(figsize=(15,9))


sns.barplot(
    x = df["lunch"],
    y = df["Average of Scores"],
    palette = 'bright'
)

plt.show()

# %% [markdown]
# **Insights**
# * Students who get Standard Lunch tend to perform better than students who got free/reduced lunch

# %% [markdown]
# #### 4.4.5 TEST PREPARATION COURSE COLUMN?
# * How many people have done the test preperation course?
# * Is Test prepration course has any impact on student's performance ?

# %% [markdown]
# ##### UNIVARIATE ANALYSIS ( HOW MANY HAVE DONE THE COURSE? )

# %%
fig, axes = plt.subplots(
    nrows = 1, 
    ncols = 2, 
    figsize = (20, 8)
)

sns.countplot(
    data = df, 
    x = df["test preparation course"], 
    palette = "PuBu", 
    hue = "gender", 
    ax = axes[0]
)

axes[0].set_title("Number of Student for Test Prep Course", size = 20)

for container in axes[0].containers:
    axes[0].bar_label(container, size = 15)

size = df["test preparation course"].value_counts()
labels = df["test preparation course"].value_counts().index
plt.pie(
    x = size, 
    labels = labels, 
    autopct='%1.1f%%',
    explode=[0.1,0],
    shadow=True
)

# %% [markdown]
# **Insights**
# * In general we have more studnets (64.2%) who have NOT completed the course compare to ones who have done (35.8%)
# * We have more female students who have done the course compare to male

# %% [markdown]
# ##### BIVARIATE ANALYSIS ( Is Test prepration course has any impact on student's performance ? )

# %%
plt.figure(figsize = (15,9))

sns.barplot(
    data = df,
    x = df["test preparation course"],
    y = df["Average of Scores"],
    palette = "flare", 
    hue = "gender"
)

plt.show()

# %% [markdown]
# **Insights**
# * Students who have completed the Test Prepration Course have scores higher in all three categories than those who haven't taken the course.

# %% [markdown]
# #### 4.4.6 MUTIVARIATE ANALYSIS USING PAIRPLOT

# %%
sns.pairplot(df,hue = 'gender')
plt.show()

# %% [markdown]
# **Insights**
# * From the above plot it is clear that all the scores increase linearly with each other.

# %% [markdown]
# # 5) **Data Visualization**
# * Student's Performance is related with lunch, race, parental level education
# * Females lead in pass percentage and also are top-scorers
# * Finishing preparation course is benefitial.
